# %% [markdown]
# *OBJETIVO: CLASSIFICAÇÃO DA BASE DE DADOS DE CANCER DE MAMA USANDO KNN*

# %%
### Pacotes necessarios:
install.packages("e1071")
install.packages("caret")
library("caret")
# Out:
# Instalando pacote em 'C:/Users/anaki/AppData/Local/R/win-library/4.4'
# (como 'lib' não foi especificado)
#
# instalando a dependência 'proxy' também
# pacote 'proxy' desempacotado com sucesso e somas MD5 verificadas
# pacote 'e1071' desempacotado com sucesso e somas MD5 verificadas
#
# Os pacotes binários baixados estão em
# 	C:\Users\anaki\AppData\Local\Temp\RtmpgJdbmX\downloaded_packages
# Instalando pacote em 'C:/Users/anaki/AppData/Local/R/win-library/4.4'
# (como 'lib' não foi especificado)
#
# instalando as dependências 'listenv', 'parallelly', 'future', 'globals', 'shape', 'future.apply', 'numDeriv', 'progressr', 'SQUAREM', 'colorspace', 'diagram', 'lava', 'farver', 'labeling', 'munsell', 'R6', 'RColorBrewer', 'viridisLite', 'pkgconfig', 'tzdb', 'cpp11', 'prodlim', 'timechange', 'stringi', 'gtable', 'isoband', 'scales', 'tibble', 'iterators', 'Rcpp', 'data.table', 'dplyr', 'clock', 'generics', 'gower', 'hardhat', 'ipred', 'lubridate', 'magrittr', 'purrr', 'tidyr', 'tidyselect', 'timeDate', 'stringr', 'ggplot2', 'foreach', 'ModelMetrics', 'plyr', 'pROC', 'recipes', 'reshape2', 'withr' também
#   Existe uma versão binária disponível, mas a versão de código-fonte é
#   posterior:
#         binary source needs_compilation
# recipes 1.0.10  1.1.0             FALSE
#
# pacote 'listenv' desempacotado com sucesso e somas MD5 verificadas
# pacote 'parallelly' desempacotado com sucesso e somas MD5 verificadas
# pacote 'future' desempacotado com sucesso e somas MD5 verificadas
# pacote 'globals' desempacotado com sucesso e somas MD5 verificadas
# pacote 'shape' desempacotado com sucesso e somas MD5 verificadas
# pacote 'future.apply' desempacotado com sucesso e somas MD5 verificadas
# pacote 'numDeriv' desempacotado com sucesso e somas MD5 verificadas
# pacote 'progressr' desempacotado com sucesso e somas MD5 verificadas
# pacote 'SQUAREM' desempacotado com sucesso e somas MD5 verificadas
# pacote 'colorspace' desempacotado com sucesso e somas MD5 verificadas
# pacote 'diagram' desempacotado com sucesso e somas MD5 verificadas
# pacote 'lava' desempacotado com sucesso e somas MD5 verificadas
# pacote 'farver' desempacotado com sucesso e somas MD5 verificadas
# pacote 'labeling' desempacotado com sucesso e somas MD5 verificadas
# pacote 'munsell' desempacotado com sucesso e somas MD5 verificadas
# pacote 'R6' desempacotado com sucesso e somas MD5 verificadas
# pacote 'RColorBrewer' desempacotado com sucesso e somas MD5 verificadas
# pacote 'viridisLite' desempacotado com sucesso e somas MD5 verificadas
# pacote 'pkgconfig' desempacotado com sucesso e somas MD5 verificadas
# pacote 'tzdb' desempacotado com sucesso e somas MD5 verificadas
# pacote 'cpp11' desempacotado com sucesso e somas MD5 verificadas
# pacote 'prodlim' desempacotado com sucesso e somas MD5 verificadas
# pacote 'timechange' desempacotado com sucesso e somas MD5 verificadas
# pacote 'stringi' desempacotado com sucesso e somas MD5 verificadas
# pacote 'gtable' desempacotado com sucesso e somas MD5 verificadas
# pacote 'isoband' desempacotado com sucesso e somas MD5 verificadas
# pacote 'scales' desempacotado com sucesso e somas MD5 verificadas
# pacote 'tibble' desempacotado com sucesso e somas MD5 verificadas
# pacote 'iterators' desempacotado com sucesso e somas MD5 verificadas
# pacote 'Rcpp' desempacotado com sucesso e somas MD5 verificadas
# pacote 'data.table' desempacotado com sucesso e somas MD5 verificadas
# pacote 'dplyr' desempacotado com sucesso e somas MD5 verificadas
# pacote 'clock' desempacotado com sucesso e somas MD5 verificadas
# pacote 'generics' desempacotado com sucesso e somas MD5 verificadas
# pacote 'gower' desempacotado com sucesso e somas MD5 verificadas
# pacote 'hardhat' desempacotado com sucesso e somas MD5 verificadas
# pacote 'ipred' desempacotado com sucesso e somas MD5 verificadas
# pacote 'lubridate' desempacotado com sucesso e somas MD5 verificadas
# pacote 'magrittr' desempacotado com sucesso e somas MD5 verificadas
# pacote 'purrr' desempacotado com sucesso e somas MD5 verificadas
# pacote 'tidyr' desempacotado com sucesso e somas MD5 verificadas
# pacote 'tidyselect' desempacotado com sucesso e somas MD5 verificadas
# pacote 'timeDate' desempacotado com sucesso e somas MD5 verificadas
# pacote 'stringr' desempacotado com sucesso e somas MD5 verificadas
# pacote 'ggplot2' desempacotado com sucesso e somas MD5 verificadas
# pacote 'foreach' desempacotado com sucesso e somas MD5 verificadas
# pacote 'ModelMetrics' desempacotado com sucesso e somas MD5 verificadas
# pacote 'plyr' desempacotado com sucesso e somas MD5 verificadas
# pacote 'pROC' desempacotado com sucesso e somas MD5 verificadas
# pacote 'reshape2' desempacotado com sucesso e somas MD5 verificadas
# pacote 'withr' desempacotado com sucesso e somas MD5 verificadas
# pacote 'caret' desempacotado com sucesso e somas MD5 verificadas
#
# Os pacotes binários baixados estão em
# 	C:\Users\anaki\AppData\Local\Temp\RtmpgJdbmX\downloaded_packages
# instalando o pacote de código-fonte 'recipes'
#
#
# Carregando pacotes exigidos: ggplot2
#
# Carregando pacotes exigidos: lattice

# %%
### Leitura dos dados

dados <- read.csv("databases/1 - Cancer de Mama - Dados.csv")

View(dados)
# Out:
#     Id  Cl.thickness Cell.size Cell.shape Marg.adhesion Epith.c.size
# 1    1   5            1         1          1            2
# 2    2   5            4         4          5            7
# 3    3   3            1         1          1            2
# 4    4   6            8         8          1            3
# 5    5   4            1         1          3            2
# 6    6   8           10        10          8            7
# 7    7   1            1         1          1            2
# 8    8   2            1         2          1            2
# 9    9   2            1         1          1            2
# 10  10   4            2         1          1            2
# 11  11   1            1         1          1            1
# 12  12   2            1         1          1            2
# 13  13   5            3         3          3            2
# 14  14   1            1         1          1            2
# 15  15   8            7         5         10            7
# 16  16   7            4         6          4            6
# 17  17   4            1         1          1            2
# 18  18   4            1         1          1            2
# 19  19  10            7         7          6            4
# 20  20   6            1         1          1            2
# 21  21   7            3         2         10            5
# 22  22  10            5         5          3            6
# 23  23   3            1         1          1            2
# 24  24   8            4         5          1            2
# 25  25   1            1         1          1            2
# 26  26   5            2         3          4            2
# 27  27   3            2         1          1            1
# 28  28   5            1         1          1            2
# 29  29   2            1         1          1            2
# 30  30   1            1         3          1            2
# ⋮   ⋮   ⋮            ⋮         ⋮          ⋮             ⋮
# 670 670  5           10        10          8            5
# 671 671  3           10         7          8            5
# 672 672  3            2         1          2            2
# 673 673  2            1         1          1            2
# 674 674  5            3         2          1            3
# 675 675  1            1         1          1            2
# 676 676  4            1         4          1            2
# 677 677  1            1         2          1            2
# 678 678  5            1         1          1            2
# 679 679  1            1         1          1            2
# 680 680  2            1         1          1            2
# 681 681 10           10        10         10            5
# 682 682  5           10        10         10            4
# 683 683  5            1         1          1            2
# 684 684  1            1         1          1            2
# 685 685  1            1         1          1            2
# 686 686  1            1         1          1            2
# 687 687  1            1         1          1            2
# 688 688  3            1         1          1            2
# 689 689  4            1         1          1            2
# 690 690  1            1         1          1            2
# 691 691  1            1         1          3            2
# 692 692  5           10        10          5            4
# 693 693  3            1         1          1            2
# 694 694  3            1         1          1            2
# 695 695  3            1         1          1            3
# 696 696  2            1         1          1            2
# 697 697  5           10        10          3            7
# 698 698  4            8         6          4            3
# 699 699  4            8         8          5            4
#     Bare.nuclei Bl.cromatin Normal.nucleoli Mitoses Class
# 1    1          3            1              1       benign
# 2   10          3            2              1       benign
# 3    2          3            1              1       benign
# 4    4          3            7              1       benign
# 5    1          3            1              1       benign
# 6   10          9            7              1       malignant
# 7   10          3            1              1       benign
# 8    1          3            1              1       benign
# 9    1          1            1              5       benign
# 10   1          2            1              1       benign
# 11   1          3            1              1       benign
# 12   1          2            1              1       benign
# 13   3          4            4              1       malignant
# 14   3          3            1              1       benign
# 15   9          5            5              4       malignant
# 16   1          4            3              1       malignant
# 17   1          2            1              1       benign
# 18   1          3            1              1       benign
# 19  10          4            1              2       malignant
# 20   1          3            1              1       benign
# 21  10          5            4              4       malignant
# 22   7          7           10              1       malignant
# 23   1          2            1              1       benign
# 24   9          7            3              1       malignant
# 25   1          3            1              1       benign
# 26   7          3            6              1       malignant
# 27   1          2            1              1       benign
# 28   1          2            1              1       benign
# 29   1          2            1              1       benign
# 30   1          1            1              1       benign
# ⋮   ⋮           ⋮           ⋮               ⋮       ⋮
# 670  5           7          10              1       malignant
# 671  8           7           4              1       malignant
# 672  1           3           1              1       benign
# 673  1           3           1              1       benign
# 674  1           1           1              1       benign
# 675  1           2           1              1       benign
# 676  1           1           1              1       benign
# 677  1           2           1              1       benign
# 678  1           1           1              1       benign
# 679  1           1           1              1       benign
# 680  1           1           1              1       benign
# 681 10          10          10              7       malignant
# 682 10           5           6              3       malignant
# 683  1           3           2              1       benign
# 684  1           1           1              1       benign
# 685  1           1           1              1       benign
# 686  1           1           1              1       benign
# 687  1           1           1              1       benign
# 688  1           2           3              1       benign
# 689  1           1           1              1       benign
# 690  1           1           1              8       benign
# 691  1           1           1              1       benign
# 692  5           4           4              1       malignant
# 693  1           1           1              1       benign
# 694  1           2           1              2       benign
# 695  2           1           1              1       benign
# 696  1           1           1              1       benign
# 697  3           8          10              2       malignant
# 698  4          10           6              1       malignant
# 699  5          10           4              1       malignant

# %%
### retira o atributo ID

dados <- dados[,-1]

View(dados)
# Out:
#     Cl.thickness Cell.size Cell.shape Marg.adhesion Epith.c.size Bare.nuclei
# 1    5            1         1          1            2             1
# 2    5            4         4          5            7            10
# 3    3            1         1          1            2             2
# 4    6            8         8          1            3             4
# 5    4            1         1          3            2             1
# 6    8           10        10          8            7            10
# 7    1            1         1          1            2            10
# 8    2            1         2          1            2             1
# 9    2            1         1          1            2             1
# 10   4            2         1          1            2             1
# 11   1            1         1          1            1             1
# 12   2            1         1          1            2             1
# 13   5            3         3          3            2             3
# 14   1            1         1          1            2             3
# 15   8            7         5         10            7             9
# 16   7            4         6          4            6             1
# 17   4            1         1          1            2             1
# 18   4            1         1          1            2             1
# 19  10            7         7          6            4            10
# 20   6            1         1          1            2             1
# 21   7            3         2         10            5            10
# 22  10            5         5          3            6             7
# 23   3            1         1          1            2             1
# 24   8            4         5          1            2             9
# 25   1            1         1          1            2             1
# 26   5            2         3          4            2             7
# 27   3            2         1          1            1             1
# 28   5            1         1          1            2             1
# 29   2            1         1          1            2             1
# 30   1            1         3          1            2             1
# ⋮   ⋮            ⋮         ⋮          ⋮             ⋮            ⋮
# 670  5           10        10          8            5             5
# 671  3           10         7          8            5             8
# 672  3            2         1          2            2             1
# 673  2            1         1          1            2             1
# 674  5            3         2          1            3             1
# 675  1            1         1          1            2             1
# 676  4            1         4          1            2             1
# 677  1            1         2          1            2             1
# 678  5            1         1          1            2             1
# 679  1            1         1          1            2             1
# 680  2            1         1          1            2             1
# 681 10           10        10         10            5            10
# 682  5           10        10         10            4            10
# 683  5            1         1          1            2             1
# 684  1            1         1          1            2             1
# 685  1            1         1          1            2             1
# 686  1            1         1          1            2             1
# 687  1            1         1          1            2             1
# 688  3            1         1          1            2             1
# 689  4            1         1          1            2             1
# 690  1            1         1          1            2             1
# 691  1            1         1          3            2             1
# 692  5           10        10          5            4             5
# 693  3            1         1          1            2             1
# 694  3            1         1          1            2             1
# 695  3            1         1          1            3             2
# 696  2            1         1          1            2             1
# 697  5           10        10          3            7             3
# 698  4            8         6          4            3             4
# 699  4            8         8          5            4             5
#     Bl.cromatin Normal.nucleoli Mitoses Class
# 1   3            1              1       benign
# 2   3            2              1       benign
# 3   3            1              1       benign
# 4   3            7              1       benign
# 5   3            1              1       benign
# 6   9            7              1       malignant
# 7   3            1              1       benign
# 8   3            1              1       benign
# 9   1            1              5       benign
# 10  2            1              1       benign
# 11  3            1              1       benign
# 12  2            1              1       benign
# 13  4            4              1       malignant
# 14  3            1              1       benign
# 15  5            5              4       malignant
# 16  4            3              1       malignant
# 17  2            1              1       benign
# 18  3            1              1       benign
# 19  4            1              2       malignant
# 20  3            1              1       benign
# 21  5            4              4       malignant
# 22  7           10              1       malignant
# 23  2            1              1       benign
# 24  7            3              1       malignant
# 25  3            1              1       benign
# 26  3            6              1       malignant
# 27  2            1              1       benign
# 28  2            1              1       benign
# 29  2            1              1       benign
# 30  1            1              1       benign
# ⋮   ⋮           ⋮               ⋮       ⋮
# 670  7          10              1       malignant
# 671  7           4              1       malignant
# 672  3           1              1       benign
# 673  3           1              1       benign
# 674  1           1              1       benign
# 675  2           1              1       benign
# 676  1           1              1       benign
# 677  2           1              1       benign
# 678  1           1              1       benign
# 679  1           1              1       benign
# 680  1           1              1       benign
# 681 10          10              7       malignant
# 682  5           6              3       malignant
# 683  3           2              1       benign
# 684  1           1              1       benign
# 685  1           1              1       benign
# 686  1           1              1       benign
# 687  1           1              1       benign
# 688  2           3              1       benign
# 689  1           1              1       benign
# 690  1           1              8       benign
# 691  1           1              1       benign
# 692  4           4              1       malignant
# 693  1           1              1       benign
# 694  2           1              2       benign
# 695  1           1              1       benign
# 696  1           1              1       benign
# 697  8          10              2       malignant
# 698 10           6              1       malignant
# 699 10           4              1       malignant

# %%
## Cria arquivos de treino e teste (80%20%) das linhas randomizadas

set.seed(123)
ran <- sample(1:nrow(dados),0.8*nrow(dados))
treino <- dados[ran,]
teste <- dados[-ran,]

# %%
## faz um grid com valores para K e executa o knn

tuneGrid <- expand.grid(k = c(1,3,5,7,9))

set.seed(123)
knn <- train(Class~.,data=treino, method="knn", tuneGrid=tuneGrid)
knn
# Out:
# k-Nearest Neighbors
#
# 559 samples
#   9 predictor
#   2 classes: 'benign', 'malignant'
#
# No pre-processing
# Resampling: Bootstrapped (25 reps)
# Summary of sample sizes: 559, 559, 559, 559, 559, 559, ...
# Resampling results across tuning parameters:
#
#   k  Accuracy   Kappa
#   1  0.9468641  0.8821989
#   3  0.9508875  0.8913603
#   5  0.9588129  0.9090424
#   7  0.9610066  0.9141424
#   9  0.9626012  0.9176942
#
# Accuracy was used to select the optimal model using the largest value.
# The final value used for the model was k = 9.

# %%
## Faz a predição e mostra a matriz de confusão

predict_knn <- predict(knn,teste)
confusionMatrix(predict_knn, as.factor(teste$Class))
# Out:
# Confusion Matrix and Statistics
#
#            Reference
# Prediction  benign malignant
#   benign        95         1
#   malignant      3        41
#
#                Accuracy : 0.9714
#                  95% CI : (0.9285, 0.9922)
#     No Information Rate : 0.7
#     P-Value [Acc > NIR] : <2e-16
#
#                   Kappa : 0.9329
#
#  Mcnemar's Test P-Value : 0.6171
#
#             Sensitivity : 0.9694
#             Specificity : 0.9762
#          Pos Pred Value : 0.9896
#          Neg Pred Value : 0.9318
#              Prevalence : 0.7000
#          Detection Rate : 0.6786
#    Detection Prevalence : 0.6857
#       Balanced Accuracy : 0.9728
#
#        'Positive' Class : benign

# %%
## Predições de novos casos

dados_novos_casos <- read.csv("databases/1 - Cancer de Mama - Dados - Novos Casos.csv")
#removendo ID
dados_novos_casos <- dados_novos_casos[,-1]

View(dados_novos_casos)
# Out:
#   Cl.thickness Cell.size Cell.shape Marg.adhesion Epith.c.size Bare.nuclei
# 1 2            1         5          1             7            1
# 2 2            3         4          5             3            1
# 3 7            1         1          5             2            2
#   Bl.cromatin Normal.nucleoli Mitoses Class
# 1 3           10              5       ?
# 2 3            2              1       ?
# 3 2            1              1       ?

# %%
predict_knn <- predict(knn, dados_novos_casos)

resultado <- cbind(dados_novos_casos, predict_knn)

resultado$Class <- NULL

View(resultado)
# Out:
#   Cl.thickness Cell.size Cell.shape Marg.adhesion Epith.c.size Bare.nuclei
# 1 2            1         5          1             7            1
# 2 2            3         4          5             3            1
# 3 7            1         1          5             2            2
#   Bl.cromatin Normal.nucleoli Mitoses predict_knn
# 1 3           10              5       benign
# 2 3            2              1       benign
# 3 2            1              1       benign
